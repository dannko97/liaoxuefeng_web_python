# %%
a = [1,2,3]
b =a

# %%
b.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ![image.png](attachment:c5ccefa7-db70-4bad-bdb5-79675cb8617e.png)

# %%
id(None)
# Out:
# 140729924803808

# %%
id(None)
# Out:
# 140729924803808

# %%
a = None
b = None
a is b
# Out:
# True

# %%
a = [1,2]
b = [1,2]
c = a

# %%
id(a) == id(c)
# Out:
# True

# %%
id(a) == id(b)
# Out:
# False

# %%
a is b
# Out:
# False

# %%
a is c
# Out:
# True

# %% [markdown]
# ![image.png](attachment:f9223d59-e5a2-4462-bc5e-191f5f6c557d.png)

# %%
a.__eq__(c)
# Out:
# True
