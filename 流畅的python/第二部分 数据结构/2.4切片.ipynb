# %% [markdown]
# ## 为什么切片和区间会忽略最后一个元素

# %% [markdown]
# ![image.png](attachment:79f77871-94b3-4ea8-938e-c2e73c293dd1.png)

# %%
 l = [10, 20, 30, 40, 50, 60]
 l[:2]
# Out:
# [10, 20]

# %%
l[2:]
# Out:
# [30, 40, 50, 60]
